# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import display

import warnings
warnings.filterwarnings("ignore")

plt.style.use('seaborn-poster')

# %%
COLUMNS = ["id", "latitude", "longitude", "text"]

PATH_TO_TRAIN = "/home/adrian/Desktop/Python/Personal/Kaggle/Geo-locationOfGermanTweets/data/training.txt"
PATH_TO_VALID = "/home/adrian/Desktop/Python/Personal/Kaggle/Geo-locationOfGermanTweets/data/validation.txt"

# %%
train_df = pd.read_csv(PATH_TO_TRAIN, sep = ',', header = None)
train_df.columns = COLUMNS

valid_df = pd.read_csv(PATH_TO_VALID, sep = ',', header = None)
valid_df.columns = COLUMNS

# %%
display(train_df)
display(valid_df)
# Out:
#            id   latitude  longitude  \
# 0      119165  51.810067  10.191331
# 1      100377  51.918188  10.599245
# 2      109550  52.711074   9.987374
# 3      111440  52.386711  11.700612
# 4      116670  52.314631   9.701835
# ...       ...        ...        ...
# 22578  120833  51.884863  10.487841
# 22579  115223  49.935479   7.051477
# 22580  119907  50.597534  12.055682
# 22581  112190  51.848082   8.554886
# 22582  110778  52.951507   9.306591
#
#                                                     text
# 0      Seit d Vase: "Wenn ich kaputt gang, bringt das...
# 1      Haha bin au w isch der amig au so richtig lang...
# 2      isch d hiltl dachterrasse amne samstig viel bs...
# 3      Ich fühle mich wie die Weimarer Republik... .....
# 4      Eui liebschte Lunchidee zum Mitneh? 😬 En Grill...
# ...                                                  ...
# 22578  Bin grad in Bus igstige, da seit de Buschauffe...
# 22579  Rien ne surpassera Dragostea Din Tei de O-zone...
# 22580  het öpert au kei bock meh zum schaffa und lust...
# 22581  Oh wenn wedermol en jodel -5 het wos ned verdi...
# 22582  Zerst hani glachet das min Kollege ändlich au ...
#
# [22583 rows x 4 columns]
#           id   latitude  longitude  \
# 0     203001  52.098389  10.354496
# 1     200313  51.629866   7.723453
# 2     201966  52.242550   8.967590
# 3     201123  52.242550   8.967590
# 4     200374  51.701946   8.416906
# ...      ...        ...        ...
# 3039  200754  52.620479  10.294545
# 3040  201772  52.841164   7.803182
# 3041  201431  51.884863   8.189773
# 3042  202066  51.774521   9.650227
# 3043  200888  52.289452   9.542841
#
#                                                    text
# 0     wenn mer anere Party bi Kollege en neue Bro fi...
# 1     Heii guetä wuchestart gha? Jo wunderbar und du...
# 2     Wieso ned? De werds eim emel ned langwiilig. O...
# 3     Hani welle vo zueri uf lausanne denn hetts e d...
# 4     Mir isch die Applikation plagiert worde as Dis...
# ...                                                 ...
# 3039  Was gits hüt schöns zum mache? 😄 (elei haha) U...
# 3040  Grad es SMS vo Salt beko: Wir haben für Sie ei...
# 3041  was lauft z chestehouz uf em hoger obe?🤔 voll ...
# 3042  Ich bin glaub scho chli en psycho ich liebs go...
# 3043  Masturbiere isch nüt anders als Liebi "ah und ...
#
# [3044 rows x 4 columns]

# %%
data = pd.concat([train_df, valid_df], axis = 0)
data = data.sample(frac = 1).reset_index(drop=True)

# %% [markdown]
# # Statistics and Distributins for latitude and longitude

# %%
rd = lambda x: np.round(x, 3)

latitude = data.latitude.values
longitude = data.longitude.values

print("Latitude  -> Min {}, Max {}, Mean {}, Std {}".format(rd(np.min(latitude)), rd(np.max(latitude)), rd(np.mean(latitude)), rd(np.std(latitude))))
print("Longitude -> Min {}, Max {}, Mean {}, Std {}".format(rd(np.min(longitude)), rd(np.max(longitude)), rd(np.mean(longitude)), rd(np.std(longitude))))
# Out:
# Latitude  -> Min 48.17, Max 53.54, Mean 51.732, Std 0.895
# Longitude -> Min 7.03, Max 12.7, Mean 9.412, Std 1.322

# %%
plt.figure(figsize = (14, 10))
plt.hist(latitude, bins = 50)
plt.title("Distribution of latitude in data")
plt.xlabel("Latitude")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (14, 10))
plt.hist(longitude, bins = 50)
plt.title("Distribution of longitude in data")
plt.xlabel("Longitude")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (20, 30))
for (i, bins) in enumerate([3, 5, 10, 20, 35, 50]):
    ax = plt.subplot(3, 2, i + 1)
    ax.hist(latitude, bins = bins)
    ax.set_title("Distribution of latitude in data with {} bins".format(bins))
    ax.set_xlabel("Latitude")
    ax.set_ylabel("Count")
    
plt.show()

# %%
plt.figure(figsize = (20, 30))
for (i, bins) in enumerate([3, 5, 10, 20, 35, 50]):
    ax = plt.subplot(3, 2, i + 1)
    ax.hist(longitude, bins = bins)
    ax.set_title("Distribution of longitude in data with {} bins".format(bins))
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Count")
    
plt.show()

# %% [markdown]
# # Tweet Lengths Distribution

# %%
data["tweet_length"] = data["text"].apply(lambda x: len(str(x)))

display(data)
# Out:
#            id   latitude  longitude  \
# 0      200671  53.359799  10.170935
# 1      113365  52.068767  10.230114
# 2      115059  51.884863  10.487841
# 3      202829  51.017181   9.518273
# 4      101588  51.884863  10.487841
# ...       ...        ...        ...
# 25622  116531  51.884863  10.487841
# 25623  120681  52.583699   7.867614
# 25624  102874  52.068767  10.230114
# 25625  202344  51.810067  10.191331
# 25626  104331  52.951507   9.306591
#
#                                                     text  tweet_length
# 0      Bier goht überall und zu jedere zit 😉 Da weisi...            93
# 1      s internet wett mer öppis sege😱 ja aber für da...           119
# 2      Wer wünscht sich amel au epis wenmer es Schaam...            71
# 3      @fraue Was sind eui erfahrige mit microblading...           214
# 4      Chunt da öpperd mit Abwasser chli drus? 🤔 Für ...           589
# ...                                                  ...           ...
# 25622  nur i dütschland😁 Wo gitz die ide schwiiz? Kei...           197
# 25623  Ka nid penne... Öbber luscht uf e belanglosi u...           508
# 25624  Ich mage nüm.. 😥 Wieso denn? Will dir kein Mit...           546
# 25625  ja schwiizerdütsch ha kei rechtschribig, aber ...           490
# 25626  Nachere halb stund hani endli die nervig mugg ...           233
#
# [25627 rows x 5 columns]

# %%
tweet_length = data.tweet_length.values

print("Tweet Lengths  -> Min {}, Max {}, Mean {}, Std {}".format(np.min(tweet_length), np.max(tweet_length), rd(np.mean(tweet_length)), rd(np.std(tweet_length))))
# Out:
# Tweet Lengths  -> Min 37, Max 750, Mean 309.098, Std 185.836

# %%
plt.figure(figsize = (20, 30))
for (i, bins) in enumerate([5, 10, 20, 35, 50, 100]):
    ax = plt.subplot(3, 2, i + 1)
    ax.hist(tweet_length, bins = bins)
    ax.set_title("Distribution of tweets lengths in data with {} bins".format(bins))
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Count")
    
plt.show()

# %%
values, counts = np.unique(tweet_length, return_counts = True)

print("Number of unique tweet lenghts: {}".format(len(values)))
# Out:
# Number of unique tweet lenghts: 664

# %% [markdown]
# # From continuous to discrete

# %%
latitude_bins      = np.digitize(latitude,     bins = [48, 49, 50, 51, 52, 53])
longitude_bins     = np.digitize(longitude,    bins = [7, 8, 9, 10, 11, 12])
tweet_length_bins  = np.digitize(tweet_length, bins = [100, 200, 300, 400, 500, 600, 700])

# %%
assert len(latitude_bins) == len(longitude_bins) == len(tweet_length_bins) == data.shape[0], "Something went wrong"

# %%
data["latitude_bins"]     = latitude_bins
data["longitude_bins"]    = longitude_bins 
data["tweet_length_bins"] = tweet_length_bins

display(data)
# Out:
#            id   latitude  longitude  \
# 0      200671  53.359799  10.170935
# 1      113365  52.068767  10.230114
# 2      115059  51.884863  10.487841
# 3      202829  51.017181   9.518273
# 4      101588  51.884863  10.487841
# ...       ...        ...        ...
# 25622  116531  51.884863  10.487841
# 25623  120681  52.583699   7.867614
# 25624  102874  52.068767  10.230114
# 25625  202344  51.810067  10.191331
# 25626  104331  52.951507   9.306591
#
#                                                     text  tweet_length  \
# 0      Bier goht überall und zu jedere zit 😉 Da weisi...            93
# 1      s internet wett mer öppis sege😱 ja aber für da...           119
# 2      Wer wünscht sich amel au epis wenmer es Schaam...            71
# 3      @fraue Was sind eui erfahrige mit microblading...           214
# 4      Chunt da öpperd mit Abwasser chli drus? 🤔 Für ...           589
# ...                                                  ...           ...
# 25622  nur i dütschland😁 Wo gitz die ide schwiiz? Kei...           197
# 25623  Ka nid penne... Öbber luscht uf e belanglosi u...           508
# 25624  Ich mage nüm.. 😥 Wieso denn? Will dir kein Mit...           546
# 25625  ja schwiizerdütsch ha kei rechtschribig, aber ...           490
# 25626  Nachere halb stund hani endli die nervig mugg ...           233
#
#        latitude_bins  longitude_bins  tweet_length_bins
# 0                  6               4                  0
# 1                  5               4                  1
# 2                  4               4                  0
# 3                  4               3                  2
# 4                  4               4                  5
# ...              ...             ...                ...
# 25622              4               4                  1
# 25623              5               1                  5
# 25624              5               4                  5
# 25625              4               4                  4
# 25626              5               3                  2
#
# [25627 rows x 8 columns]

# %%
group_by_latitude = data.groupby("latitude_bins")["longitude"].describe()
display(group_by_latitude)

group_by_latitude = data.groupby("latitude_bins")["tweet_length"].describe()
display(group_by_latitude)
# Out:
#                  count       mean       std       min        25%        50%  \
# latitude_bins
# 1                159.0   8.534316  0.214213  7.674318   8.426023   8.641259
# 2                709.0   7.891880  0.247779  7.051477   7.889091   7.889091
# 3               5221.0   9.213800  1.741131  7.030000   7.609886   9.349545
# 4               7393.0   9.489729  1.157224  7.051477   8.554886   9.800568
# 5              11835.0   9.534617  1.185579  7.287727   8.376115   9.800568
# 6                310.0  10.101751  0.267836  9.628750  10.036818  10.036818
#
#                      75%        max
# latitude_bins
# 1               8.662273   8.865612
# 2               7.889091  12.549659
# 3              10.079773  12.700000
# 4              10.273068  12.047338
# 5              10.294545  12.230899
# 6              10.058295  11.353885
#                  count        mean         std   min     25%    50%    75%  \
# latitude_bins
# 1                159.0  202.427673  153.438210  54.0   89.00  145.0  251.0
# 2                709.0  277.867419  175.899904  46.0  119.00  216.0  472.0
# 3               5221.0  303.077380  183.903984  41.0  132.00  257.0  502.0
# 4               7393.0  296.321115  183.701492  37.0  127.00  240.0  498.0
# 5              11835.0  324.811998  187.694149  40.0  148.00  292.0  522.0
# 6                310.0  241.448387  163.614223  46.0  112.75  189.0  317.0
#
#                  max
# latitude_bins
# 1              652.0
# 2              643.0
# 3              703.0
# 4              750.0
# 5              734.0
# 6              676.0

# %%
group_by_longitude = data.groupby("longitude_bins")["latitude"].describe()
display(group_by_longitude)

group_by_longitude = data.groupby("longitude_bins")["tweet_length"].describe()
display(group_by_longitude)
# Out:
#                  count       mean       std        min        25%        50%  \
# longitude_bins
# 1               6282.0  51.319869  1.068302  48.170000  50.440537  51.112466
# 2               2909.0  51.822485  1.031214  48.170000  51.701946  52.179110
# 3               7461.0  51.889685  0.655848  50.266507  51.406712  52.142329
# 4               6307.0  51.990969  0.697182  50.009041  51.774521  52.068767
# 5               1852.0  51.971486  0.768934  50.082603  51.848082  52.363014
# 6                816.0  50.585138  0.172909  49.935479  50.597534  50.597534
#
#                       75%        max
# longitude_bins
# 1               52.583699  52.914726
# 2               52.473356  52.927315
# 3               52.546918  53.540000
# 4               52.546918  53.359799
# 5               52.363014  53.215638
# 6               50.597534  52.458792
#                  count        mean         std   min     25%    50%     75%  \
# longitude_bins
# 1               6282.0  305.102356  182.891848  41.0  133.25  262.0  502.00
# 2               2909.0  289.123754  180.982389  44.0  126.00  233.0  489.00
# 3               7461.0  316.564268  187.381891  41.0  141.00  274.0  519.00
# 4               6307.0  313.512605  187.386523  37.0  138.00  270.0  515.00
# 5               1852.0  305.157667  189.209622  40.0  136.00  250.5  501.25
# 6                816.0  317.629902  185.915180  41.0  142.00  286.0  516.25
#
#                   max
# longitude_bins
# 1               704.0
# 2               684.0
# 3               750.0
# 4               734.0
# 5               731.0
# 6               661.0

# %%
group_by_tweet_count = data.groupby("tweet_length_bins")["latitude"].describe()
display(group_by_tweet_count)

group_by_tweet_count = data.groupby("tweet_length_bins")["longitude"].describe()
display(group_by_tweet_count)
# Out:
#                     count       mean       std        min        25%  \
# tweet_length_bins
# 0                  3526.0  51.638430  0.949775  48.170000  50.965342
# 1                  6673.0  51.692813  0.921380  48.170000  51.002123
# 2                  3720.0  51.736723  0.906116  48.170000  51.112466
# 3                  2337.0  51.754473  0.868332  48.170000  51.222808
# 4                  2426.0  51.722348  0.874864  48.170000  50.981141
# 5                  6172.0  51.792163  0.845953  48.170000  51.296370
# 6                   753.0  51.941190  0.809953  48.170000  51.629866
# 7                    20.0  52.112768  0.611004  50.404497  51.940034
#
#                          50%        75%        max
# tweet_length_bins
# 0                  51.774521  52.473356  53.540000
# 1                  51.848082  52.510137  53.540000
# 2                  51.884863  52.530872  53.540000
# 3                  51.918188  52.546918  53.359799
# 4                  51.884863  52.546918  53.359799
# 5                  52.068767  52.546918  53.540000
# 6                  52.142329  52.546918  53.359799
# 7                  52.326233  52.363014  52.855235
#                     count       mean       std       min       25%        50%  \
# tweet_length_bins
# 0                  3526.0   9.376416  1.352709  7.030000  7.928569   9.564318
# 1                  6673.0   9.384923  1.330854  7.030000  8.049784   9.650227
# 2                  3720.0   9.443912  1.312737  7.030000  8.125341   9.650227
# 3                  2337.0   9.396563  1.305146  7.030000  8.049784   9.650227
# 4                  2426.0   9.341685  1.351123  7.030000  7.889091   9.650227
# 5                  6172.0   9.430011  1.296305  7.030000  8.110971   9.650227
# 6                   753.0   9.744008  1.233341  7.030000  9.070341   9.843523
# 7                    20.0  10.435585  1.429488  7.330682  9.904748  10.721619
#
#                          75%        max
# tweet_length_bins
# 0                  10.273068  12.700000
# 1                  10.230114  12.700000
# 2                  10.230114  12.700000
# 3                  10.230114  12.700000
# 4                  10.230114  12.700000
# 5                  10.294545  12.700000
# 6                  10.358977  12.700000
# 7                  11.647614  11.647614

# %%
PATH_TO_PREPROCCESED_TRAIN = "/home/adrian/Desktop/Python/Personal/Kaggle/Geo-locationOfGermanTweets/data/preprocessed/preprocessed_train.csv"
PATH_TO_PREPROCCESED_VALID = "/home/adrian/Desktop/Python/Personal/Kaggle/Geo-locationOfGermanTweets/data/preprocessed/preprocessed_valid.csv"

# %%
preproccesed_train = pd.read_csv(PATH_TO_PREPROCCESED_TRAIN)
preproccesed_valid = pd.read_csv(PATH_TO_PREPROCCESED_VALID)

preproccesed_data = pd.concat([preproccesed_train, preproccesed_valid], axis = 0)
preproccesed_data = preproccesed_data.sample(frac = 1).reset_index(drop=True)

# %%
display(preproccesed_data)
# Out:
#            id   latitude  longitude  \
# 0      113136  51.884863  10.487841
# 1      118114  52.215890   8.769659
# 2      119171  52.841164   7.803182
# 3      106554  51.774521  10.058295
# 4      102714  50.597534   7.502500
# ...       ...        ...        ...
# 25622  116271  52.215890   8.769659
# 25623  114447  53.319315  10.294545
# 25624  110512  51.075685   9.628750
# 25625  111104  52.804384   7.695795
# 25626  120947  52.215890   9.070341
#
#                                                     text  \
# 0      Vorschlag fürs Unwort des Jahres: Social Media...
# 1      Ih ha kei Ahnig wie min ex zit für en Affäre g...
# 2      Leute ich ha grad öbis gseh woni so schnell ni...
# 3      Es git bessers im Lebe als Tramfahre😴 #Forchtr...
# 4      I bi 18. Ha e ruhepuls vo 52 und bi ke profisp...
# ...                                                  ...
# 25622  Die Lüt wo der em Zug visavis heresetze emne 4...
# 25623  Bin grad mini summer playlist am zemestelle un...
# 25624  Wie tür esch 1h pedalo miete z luzern? weiss d...
# 25625  Fact of the day Vin diesel wird hüt 50 aber he...
# 25626  liebi SBB.. Saftlade.. Kenne de bahnübergang i...
#
#                                               final_text
# 0      vorschlag fürs unwort jahres social media infl...
# 1      ih ha kei ahnig min ex zit en affäre gfunde he...
# 2      leute ha grad öbis gseh woni schnellen nid ver...
# 3      git bessers leben tramfahre forchtram de schäb...
# 4      i bi 18 ha e ruhepuls vo 52 bi ke profisportle...
# ...                                                  ...
# 25622  lüt em zug visavis heresetze emne 4er abteil o...
# 25623  grad mini summer playlist zemestelle sueche na...
# 25624  tür esch 1h pedalo miete z luzern weiss öper e...
# 25625  fact of the day vin diesel hüt 50 het no kei e...
# 25626  liebi sbb saftlade kennen de bahnübergang hend...
#
# [25627 rows x 5 columns]

# %%
preproccesed_data["tweet_length"]       = preproccesed_data["text"].apply(lambda x: len(str(x)))
preproccesed_data["final_tweet_length"] = preproccesed_data["final_text"].apply(lambda x: len(str(x)))
preproccesed_data["length_diff"]        = preproccesed_data["tweet_length"] - preproccesed_data["final_tweet_length"] 

display(preproccesed_data)
# Out:
#            id   latitude  longitude  \
# 0      113136  51.884863  10.487841
# 1      118114  52.215890   8.769659
# 2      119171  52.841164   7.803182
# 3      106554  51.774521  10.058295
# 4      102714  50.597534   7.502500
# ...       ...        ...        ...
# 25622  116271  52.215890   8.769659
# 25623  114447  53.319315  10.294545
# 25624  110512  51.075685   9.628750
# 25625  111104  52.804384   7.695795
# 25626  120947  52.215890   9.070341
#
#                                                     text  \
# 0      Vorschlag fürs Unwort des Jahres: Social Media...
# 1      Ih ha kei Ahnig wie min ex zit für en Affäre g...
# 2      Leute ich ha grad öbis gseh woni so schnell ni...
# 3      Es git bessers im Lebe als Tramfahre😴 #Forchtr...
# 4      I bi 18. Ha e ruhepuls vo 52 und bi ke profisp...
# ...                                                  ...
# 25622  Die Lüt wo der em Zug visavis heresetze emne 4...
# 25623  Bin grad mini summer playlist am zemestelle un...
# 25624  Wie tür esch 1h pedalo miete z luzern? weiss d...
# 25625  Fact of the day Vin diesel wird hüt 50 aber he...
# 25626  liebi SBB.. Saftlade.. Kenne de bahnübergang i...
#
#                                               final_text  tweet_length  \
# 0      vorschlag fürs unwort jahres social media infl...           111
# 1      ih ha kei ahnig min ex zit en affäre gfunde he...           136
# 2      leute ha grad öbis gseh woni schnellen nid ver...           101
# 3      git bessers leben tramfahre forchtram de schäb...           306
# 4      i bi 18 ha e ruhepuls vo 52 bi ke profisportle...           502
# ...                                                  ...           ...
# 25622  lüt em zug visavis heresetze emne 4er abteil o...           595
# 25623  grad mini summer playlist zemestelle sueche na...           471
# 25624  tür esch 1h pedalo miete z luzern weiss öper e...           297
# 25625  fact of the day vin diesel hüt 50 het no kei e...           164
# 25626  liebi sbb saftlade kennen de bahnübergang hend...           584
#
#        final_tweet_length  length_diff
# 0                      94           17
# 1                     114           22
# 2                      84           17
# 3                     255           51
# 4                     421           81
# ...                   ...          ...
# 25622                 511           84
# 25623                 402           69
# 25624                 247           50
# 25625                 135           29
# 25626                 440          144
#
# [25627 rows x 8 columns]

# %%
length_diff = preproccesed_data.length_diff.values

print("Tweet Lengths Diff -> Min {}, Max {}, Mean {}, Std {}".format(np.min(length_diff), np.max(length_diff), rd(np.mean(length_diff)), rd(np.std(length_diff))))
# Out:
# Tweet Lengths Diff -> Min -2, Max 324, Mean 63.407, Std 45.308

# %%
PATH_TO_LEVEL_ONE_FEATURES = "/home/adrian/Desktop/Python/Personal/Kaggle/Geo-locationOfGermanTweets/data/level_one/level_one_features.csv"
level_one_features = pd.read_csv(PATH_TO_LEVEL_ONE_FEATURES)

display(level_one_features)
# Out:
#         latitude  longitude  feature_latitude_0  feature_longitude_0  \
# 0      50.303288  12.700000           52.096359            10.151499
# 1      52.510137  10.938864           52.075672            10.383677
# 2      52.841164   7.803182           52.127438             9.644189
# 3      52.546918   7.588409           52.301120             8.218519
# 4      52.215890   9.070341           52.003456             9.743672
# ...          ...        ...                 ...                  ...
# 25622  52.289452   9.542841           52.090049            10.257087
# 25623  51.406712   9.306591           51.995980             9.152029
# 25624  52.142329  10.358977           52.073451             9.531595
# 25625  52.142329   9.843523           52.159217            10.151507
# 25626  50.981141   7.417518           51.214442             8.145559
#
#        feature_latitude_1  feature_longitude_1  feature_latitude_2  \
# 0               52.128016            10.937544           51.566358
# 1               51.880118            10.081896           52.164974
# 2               52.270584             9.357008           52.357504
# 3               52.462414             8.058661           52.661042
# 4               52.209941             9.696445           52.073617
# ...                   ...                  ...                 ...
# 25622           52.015461            10.214070           52.016647
# 25623           51.759059             9.561379           52.348089
# 25624           51.926058            10.045235           52.239208
# 25625           52.178545             9.935761           52.222769
# 25626           51.732142             7.885671           50.942639
#
#        feature_longitude_2  feature_latitude_3  feature_longitude_3  ...  \
# 0                10.756435           51.540883            10.739553  ...
# 1                10.254776           52.144663            10.322766  ...
# 2                 9.997081           52.330304             9.943013  ...
# 3                 7.890974           52.646297             7.907686  ...
# 4                 9.432688           52.077387             9.490349  ...
# ...                    ...                 ...                  ...  ...
# 25622            10.090662           52.014561            10.131272  ...
# 25623             8.813775           52.305742             8.817897  ...
# 25624             9.671488           52.279045             9.575360  ...
# 25625            10.057343           52.245688            10.049517  ...
# 25626             7.849388           50.940569             7.814992  ...
#
#        feature_latitude_36  feature_longitude_36  feature_latitude_37  \
# 0                51.845686             10.401475            52.058729
# 1                52.044254             10.553486            52.112185
# 2                51.986483              9.021135            51.855564
# 3                52.381890              9.197784            52.305834
# 4                51.859300              9.297199            51.817668
# ...                    ...                   ...                  ...
# 25622            51.757047             10.032426            51.794041
# 25623            51.889808              9.514816            51.936475
# 25624            52.184173              9.898017            52.098340
# 25625            52.276862              9.890918            52.120153
# 25626            51.450198              8.419599            51.546495
#
#        feature_longitude_37  feature_latitude_38  feature_longitude_38  \
# 0                  9.894382            51.914214             10.130999
# 1                 10.628869            52.017775             10.513285
# 2                  8.947239            51.898485              9.077673
# 3                  9.387273            52.348679              9.324329
# 4                  9.342161            51.838743              9.311745
# ...                     ...                  ...                   ...
# 25622              9.830043            51.772051              9.914258
# 25623              9.486846            51.874641              9.511725
# 25624              9.880609            52.170230              9.899737
# 25625              9.796202            52.191247              9.826035
# 25626              8.392872            51.454762              8.432373
#
#        feature_latitude_39  feature_longitude_39  feature_latitude_40  \
# 0                51.873085             10.177932            51.872735
# 1                52.023261             10.451432            52.040390
# 2                51.912978              9.078296            51.921588
# 3                52.327147              9.336431            52.308855
# 4                51.824880              9.340813            51.813268
# ...                    ...                   ...                  ...
# 25622            51.767497              9.921769            51.777928
# 25623            51.856078              9.519345            51.860124
# 25624            52.170826              9.880283            52.162419
# 25625            52.213920              9.848949            52.219128
# 25626            51.454163              8.480392            51.459577
#
#        feature_longitude_40
# 0                 10.172318
# 1                 10.417164
# 2                  9.076651
# 3                  9.340920
# 4                  9.360364
# ...                     ...
# 25622              9.930596
# 25623              9.506750
# 25624              9.866058
# 25625              9.846165
# 25626              8.502510
#
# [25627 rows x 84 columns]

# %%
latitude  = level_one_features.latitude.values
longitude = level_one_features.longitude.values

latitude_bins      = np.digitize(latitude,     bins = [48, 49, 50, 51, 52, 53])
longitude_bins     = np.digitize(longitude,    bins = [7, 8, 9, 10, 11, 12])

level_one_features["latitude_skf"]  = latitude_bins
level_one_features["longitude_skf"] = longitude_bins

display(level_one_features)

PATH_TO_LEVEL_ONE_FEATURES_SKF = "/home/adrian/Desktop/Python/Personal/Kaggle/Geo-locationOfGermanTweets/data/level_one/level_one_features_skf.csv"
level_one_features.to_csv(PATH_TO_LEVEL_ONE_FEATURES_SKF, index = False)
# Out:
#         latitude  longitude  feature_latitude_0  feature_longitude_0  \
# 0      50.303288  12.700000           52.096359            10.151499
# 1      52.510137  10.938864           52.075672            10.383677
# 2      52.841164   7.803182           52.127438             9.644189
# 3      52.546918   7.588409           52.301120             8.218519
# 4      52.215890   9.070341           52.003456             9.743672
# ...          ...        ...                 ...                  ...
# 25622  52.289452   9.542841           52.090049            10.257087
# 25623  51.406712   9.306591           51.995980             9.152029
# 25624  52.142329  10.358977           52.073451             9.531595
# 25625  52.142329   9.843523           52.159217            10.151507
# 25626  50.981141   7.417518           51.214442             8.145559
#
#        feature_latitude_1  feature_longitude_1  feature_latitude_2  \
# 0               52.128016            10.937544           51.566358
# 1               51.880118            10.081896           52.164974
# 2               52.270584             9.357008           52.357504
# 3               52.462414             8.058661           52.661042
# 4               52.209941             9.696445           52.073617
# ...                   ...                  ...                 ...
# 25622           52.015461            10.214070           52.016647
# 25623           51.759059             9.561379           52.348089
# 25624           51.926058            10.045235           52.239208
# 25625           52.178545             9.935761           52.222769
# 25626           51.732142             7.885671           50.942639
#
#        feature_longitude_2  feature_latitude_3  feature_longitude_3  ...  \
# 0                10.756435           51.540883            10.739553  ...
# 1                10.254776           52.144663            10.322766  ...
# 2                 9.997081           52.330304             9.943013  ...
# 3                 7.890974           52.646297             7.907686  ...
# 4                 9.432688           52.077387             9.490349  ...
# ...                    ...                 ...                  ...  ...
# 25622            10.090662           52.014561            10.131272  ...
# 25623             8.813775           52.305742             8.817897  ...
# 25624             9.671488           52.279045             9.575360  ...
# 25625            10.057343           52.245688            10.049517  ...
# 25626             7.849388           50.940569             7.814992  ...
#
#        feature_latitude_37  feature_longitude_37  feature_latitude_38  \
# 0                52.058729              9.894382            51.914214
# 1                52.112185             10.628869            52.017775
# 2                51.855564              8.947239            51.898485
# 3                52.305834              9.387273            52.348679
# 4                51.817668              9.342161            51.838743
# ...                    ...                   ...                  ...
# 25622            51.794041              9.830043            51.772051
# 25623            51.936475              9.486846            51.874641
# 25624            52.098340              9.880609            52.170230
# 25625            52.120153              9.796202            52.191247
# 25626            51.546495              8.392872            51.454762
#
#        feature_longitude_38  feature_latitude_39  feature_longitude_39  \
# 0                 10.130999            51.873085             10.177932
# 1                 10.513285            52.023261             10.451432
# 2                  9.077673            51.912978              9.078296
# 3                  9.324329            52.327147              9.336431
# 4                  9.311745            51.824880              9.340813
# ...                     ...                  ...                   ...
# 25622              9.914258            51.767497              9.921769
# 25623              9.511725            51.856078              9.519345
# 25624              9.899737            52.170826              9.880283
# 25625              9.826035            52.213920              9.848949
# 25626              8.432373            51.454163              8.480392
#
#        feature_latitude_40  feature_longitude_40  latitude_skf  longitude_skf
# 0                51.872735             10.172318             3              6
# 1                52.040390             10.417164             5              4
# 2                51.921588              9.076651             5              1
# 3                52.308855              9.340920             5              1
# 4                51.813268              9.360364             5              3
# ...                    ...                   ...           ...            ...
# 25622            51.777928              9.930596             5              3
# 25623            51.860124              9.506750             4              3
# 25624            52.162419              9.866058             5              4
# 25625            52.219128              9.846165             5              3
# 25626            51.459577              8.502510             3              1
#
# [25627 rows x 86 columns]
